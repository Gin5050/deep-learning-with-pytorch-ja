# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/MyStudy/dlwpt-code-ja/
# Out:
# /content/drive/MyDrive/MyStudy/dlwpt-code-ja

# %%
# !pwd
# Out:
# /content/drive/MyDrive/MyStudy/dlwpt-code-ja

# %%
import sys
sys.path.append('drive/MyDrive/Mystudy/dlwpt-code-ja/')
# %matplotlib inline
import numpy as np

# %%
# !pip install SimpleITK
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.10/dist-packages (2.2.1)

# %%
# !pip install cassandra-driver
# Out:
# Requirement already satisfied: cassandra-driver in /usr/local/lib/python3.10/dist-packages (3.28.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from cassandra-driver) (1.16.0)
# Requirement already satisfied: geomet<0.3,>=0.1 in /usr/local/lib/python3.10/dist-packages (from cassandra-driver) (0.2.1.post1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geomet<0.3,>=0.1->cassandra-driver) (8.1.6)

# %%
# !pip install diskcache
# Out:
# Requirement already satisfied: diskcache in /usr/local/lib/python3.10/dist-packages (5.6.1)

# %%
from p2ch10.dsets import getCandidateInfoList, getCt, LunaDataset
candidateInfo_list = getCandidateInfoList(requireOnDisk_bool=False)
positiveInfo_list = [x for x in candidateInfo_list if x[0]]
diameter_list = [x[1] for x in positiveInfo_list]

# %%
print(len(positiveInfo_list))
print(positiveInfo_list[0])
# Out:
# 1351
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.61451718, 85.02525992, -109.8084416))

# %%
for i in range(0, len(diameter_list), 100):
    print('{:4}  {:4.1f} mm'.format(i, diameter_list[i]))
# Out:
#    0  32.3 mm
#  100  17.7 mm
#  200  13.0 mm
#  300  10.0 mm
#  400   8.2 mm
#  500   7.0 mm
#  600   6.3 mm
#  700   5.7 mm
#  800   5.1 mm
#  900   4.7 mm
# 1000   4.0 mm
# 1100   0.0 mm
# 1200   0.0 mm
# 1300   0.0 mm

# %%
for candidateInfo_tup in positiveInfo_list[:10]:
    print(candidateInfo_tup)
for candidateInfo_tup in positiveInfo_list[-10:]:
    print(candidateInfo_tup)

for candidateInfo_tup in positiveInfo_list:
    if candidateInfo_tup.series_uid.endswith('565'):
        print(candidateInfo_tup)
# Out:
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.61451718, 85.02525992, -109.8084416))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(47.90350511, 37.60442008, -99.93417567))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(44.19, 37.79, -107.01))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(40.69, 32.19, -97.15))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=27.44242293, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.943403138251347598519939390311', center_xyz=(-45.29440163, 74.86925386, -97.52812481))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=27.07544345, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.481278873893653517789960724156', center_xyz=(-102.571208, -5.186558766, -205.1033412))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=26.83708074, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754493433372433148666', center_xyz=(121.152909372, 12.9136003304, -159.399497186))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=26.83708074, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754493433372433148666', center_xyz=(118.8539408, 11.54202797, -165.5042458))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=25.87269662, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.177086402277715068525592995222', center_xyz=(-66.628286875, 57.151972075, -110.12035075))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=25.41540526, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219618492426142913407827034169', center_xyz=(-101.7504204, -95.65460516, -138.4943211))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.107109359065300889765026303943', center_xyz=(-100.57, -66.23, -218.76))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.106379658920626694402549886949', center_xyz=(-71.09, 68.3, -160.4))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', center_xyz=(106.18, 12.61, -96.81))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', center_xyz=(96.2846726653, 19.0348690723, -88.478440818))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(89.32, 190.84, -516.82))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(89.32, 143.23, -427.1))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(85.12, 152.33, -425.7))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(8.8, 174.74, -401.87))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(5.99, 171.94, -398.37))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(1.79, 166.34, -408.88))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93))

# %%
np.histogram(diameter_list)
# Out:
# (array([323, 466, 248, 111,  71,  57,  37,  29,   5,   4]),
#  array([ 0.        ,  3.22700302,  6.45400605,  9.68100907, 12.9080121 ,
#         16.13501512, 19.36201815, 22.58902117, 25.8160242 , 29.04302722,
#         32.27003025]))

# %%
from p2ch10.vis import findPositiveSamples, showCandidate
positiveSample_list = findPositiveSamples()
# Out:
# 2023-08-11 01:06:53,162 INFO     pid:348 p2ch10.dsets:177:__init__ <p2ch10.dsets.LunaDataset object at 0x7a66456e9990>: 56938 training samples
# 0 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.310399552, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.979083010707182900091062408058', center_xyz=(-102.84092514, 57.8809154545, -124.815520253))
# 1 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.681381581, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987', center_xyz=(136.31, 116.67, -181.89))
# 2 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.784886899, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(96.5080202269, 213.298021661, -613.21058414))
# 3 CandidateInfoTuple(isNodule_bool=True, diameter_mm=19.65387738, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.752756872840730509471096155114', center_xyz=(56.1226132601, 67.868268695, -65.6269886453))
# 4 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.83118822, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.249530219848512542668813996730', center_xyz=(124.200923089, 65.8035261302, -210.521147465))
# 5 CandidateInfoTuple(isNodule_bool=True, diameter_mm=12.02215382, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.430109407146633213496148200410', center_xyz=(-45.86281408, -106.11146345, -147.91194395))
# 6 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.053719722, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-84.3086034783, -42.2047464888, -146.649587983))
# 7 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(44.25, 52.17, -110.25))
# 8 CandidateInfoTuple(isNodule_bool=True, diameter_mm=15.48525426, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227', center_xyz=(-57.04638761, 131.2249427, -520.247305))
# 9 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.720277435, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354', center_xyz=(59.73, -157.0, -119.49))
# 10 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.253525386, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.241570579760883349458693655367', center_xyz=(-124.08, 127.67, 1633.06))
# 11 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.091312581, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.716498695101447665580610403574', center_xyz=(-68.2895869858, -109.992924453, -96.9283020516))
# 12 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.556944532, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.294188507421106424248264912111', center_xyz=(-85.01, 53.4, -281.93))
# 13 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.752756872840730509471096155114', center_xyz=(55.23, 62.63, -63.5))
# 14 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.48732767, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.621916089407825046337959219998', center_xyz=(-97.330389555, 45.02276113, -155.38801195))
# 15 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.905371958588660410240398317235', center_xyz=(110.83, 57.69, -122.43))
# 16 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.259551508, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.141069661700670042960678408762', center_xyz=(-102.01, 248.56, -739.43))
# 17 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.511347030803753100045216493273', center_xyz=(59.1136546856, 82.9816128068, -213.127954744))
# 18 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-82.01161135, 186.5539408, -467.9168457))
# 19 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.430802339, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.868211851413924881662621747734', center_xyz=(-22.82, 77.77, -135.81))
# 20 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493', center_xyz=(-80.7, 58.42, -131.12))
# 21 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.678130013, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.898642529028521482602829374444', center_xyz=(-41.92, 92.28, -566.23))
# 22 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-81.05, 190.54, -462.17))
# 23 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.673547135, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179', center_xyz=(99.3146639166, 66.0098225079, -90.5268699307))
# 24 CandidateInfoTuple(isNodule_bool=True, diameter_mm=12.80135622, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.534006575256943390479252771547', center_xyz=(-92.8243371229, 62.3770624293, -95.1800403034))
# 25 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.430109407146633213496148200410', center_xyz=(34.43, -121.28, -109.99))
# 26 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.64560862, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.525937963993475482158828421281', center_xyz=(127.2868873, 70.71304151, -91.86194784))
# 27 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.14006008, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.313835996725364342034830119490', center_xyz=(-103.606170996, 5.07017220203, -45.0445111659))
# 28 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.717405126, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.277445975068759205899107114231', center_xyz=(-48.6932637254, -65.6001064436, -209.327417951))
# 29 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.028864971, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.272042302501586336192628818865', center_xyz=(36.8743693547, 178.560521522, -603.254348044))
# 30 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.93827513, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-55.911605232, 175.416751344, -405.328583147))
# 31 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.17547004, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.450501966058662668272378865145', center_xyz=(52.955066627, 21.5829057375, 232.603987857))
# 32 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.96263215, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(53.8710070042, 139.156354144, -625.795207073))
# 33 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.982986958, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.194440094986948071643661798326', center_xyz=(56.38967842, -92.71316409, -275.8592896))
# 34 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-78.2266125547, 180.542140994, -467.88476912))
# 35 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.244643239, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.334517907433161353885866806005', center_xyz=(-113.4793963, 127.8996568, -452.72309185))
# 36 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(36.54, 78.1, -122.92))
# 37 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.813145858, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729', center_xyz=(-61.1318931033, 224.376802237, -633.722209393))
# 38 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.4626083, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912', center_xyz=(34.1223242148, 87.8273440723, -100.189149775))
# 39 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.58311204, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.905371958588660410240398317235', center_xyz=(109.142472723, 49.6356928166, -121.183579092))
# 40 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.395623571499047043765181005112', center_xyz=(-63.6579593186, -5.12494885712, -84.1339055592))
# 41 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.965579845, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.534083630500464995109143618896', center_xyz=(-86.8, 56.07, -112.26))
# 42 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.127950372, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.868211851413924881662621747734', center_xyz=(-8.81, 58.85, -109.84))
# 43 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.283782817, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.534006575256943390479252771547', center_xyz=(125.05, -9.15, -208.18))
# 44 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.800248866, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.129055977637338639741695800950', center_xyz=(-95.430332199, -87.6984598229, 1131.88013133))
# 45 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.888814398, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-69.3825, 56.288020835, -81.68967418))
# 46 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.722280115, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.294188507421106424248264912111', center_xyz=(100.03, 54.1, -256.65))
# 47 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.75323185, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(94.1132711884, -15.8936132585, -202.847228297))
# 48 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.84883567, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179', center_xyz=(119.314454061, 19.1701643762, -155.143581615))
# 49 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.59647134, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(46.00314143, 47.66525294, -108.4822128))
# 50 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.418028913, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.430109407146633213496148200410', center_xyz=(97.47, -97.09, -215.49))
# 51 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.368487089, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.868211851413924881662621747734', center_xyz=(-81.68, 82.68, -167.4))
# 52 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.98914009, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.511347030803753100045216493273', center_xyz=(-108.732902775, -38.2541652087, -199.158196279))
# 53 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.903510371, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.294188507421106424248264912111', center_xyz=(120.42003855, 26.50582658, -282.61165745))
# 54 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.10051888, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729', center_xyz=(-64.88987189, 196.9697692, -469.20840415))
# 55 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.244054524, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.724251104254976962355686318345', center_xyz=(-58.8, 147.35, -647.99))
# 56 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.090964239, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.534083630500464995109143618896', center_xyz=(-41.95, -2.79, -114.37))
# 57 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.247278653, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.293757615532132808762625441831', center_xyz=(-67.45, -40.62, -172.12))
# 58 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.905371958588660410240398317235', center_xyz=(103.710144289, 42.3480198092, -119.266765088))
# 59 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.063233243, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.404364125369979066736354549484', center_xyz=(97.84, -79.43, -202.46))
# 60 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.242190906, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.249530219848512542668813996730', center_xyz=(145.81, 33.61, -189.8))
# 61 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.6734543, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.295298571102631191572192562523', center_xyz=(-132.04, -3.6, -221.38))
# 62 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.295420274214095686326263147663', center_xyz=(-69.85, 42.51, -160.24))
# 63 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.060034849, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.303421828981831854739626597495', center_xyz=(91.25, 136.51, 1521.6))
# 64 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.614419285, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.323859712968543712594665815359', center_xyz=(-56.75, 44.15, -79.6))
# 65 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.972916889, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.305858704835252413616501469037', center_xyz=(-60.82, 227.03, -378.95))
# 66 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.253917448, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.305858704835252413616501469037', center_xyz=(22.744456585, 196.0703828, -367.29208485))
# 67 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227', center_xyz=(-52.48, 135.05, -521.24))
# 68 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.05335657, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(65.9819404529, 65.3748482043, -245.07371322))
# 69 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517', center_xyz=(-88.91, -4.8, -80.76))
# 70 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.98502287, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.826812708000318290301835871780', center_xyz=(-42.25, -52.72, -128.45))
# 71 CandidateInfoTuple(isNodule_bool=True, diameter_mm=18.7832325, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196', center_xyz=(-82.79150362, -21.43587141, -97.18427459))
# 72 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.05940652, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.130438550890816550994739120843', center_xyz=(88.4711209658, 32.9338043994, -78.2315830223))
# 73 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.566816709786169715745131047975', center_xyz=(-124.56, 21.03, -167.84))
# 74 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(94.8682494235, -22.4152582646, -208.030982511))
# 75 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.3362496, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.805925269324902055566754756843', center_xyz=(-66.8081081882, 97.0125969393, -267.863533051))
# 76 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.277445975068759205899107114231', center_xyz=(-57.6598012339, -86.2943191693, -216.503587558))
# 77 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.805925269324902055566754756843', center_xyz=(-73.46, 97.11, -267.55))
# 78 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.52596027, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223', center_xyz=(75.0930413723, -0.51240559114, -58.1161965725))
# 79 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93))
# 80 CandidateInfoTuple(isNodule_bool=True, diameter_mm=25.23320204, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.511347030803753100045216493273', center_xyz=(63.4740118048, 73.9174523314, -213.736128767))
# 81 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.364989395, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.310548927038333190233889983845', center_xyz=(-45.2427079881, 57.3521070453, -64.0080443316))
# 82 CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.661014906, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517', center_xyz=(-86.81, -17.42, -51.97))
# 83 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196', center_xyz=(-85.8668496571, -26.6501938805, -95.2879167459))
# 84 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.09125367, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.295420274214095686326263147663', center_xyz=(-65.9640510945, 81.2984155672, -179.11789495))
# 85 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223', center_xyz=(77.1171358377, -6.7515977048, -53.8551263442))
# 86 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-86.9514169487, 162.142965995, -455.060669104))
# 87 CandidateInfoTuple(isNodule_bool=True, diameter_mm=12.68580657, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.313334055029671473836954456733', center_xyz=(67.68450126, 44.02446338, -265.684528))
# 88 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.36498067, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.295420274214095686326263147663', center_xyz=(-68.45, 88.75, -190.46))
# 89 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.898642529028521482602829374444', center_xyz=(75.62, 111.88, -533.24))
# 90 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.000523906, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.295420274214095686326263147663', center_xyz=(-46.1961954943, 75.8948313553, -161.12479227))
# 91 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.440878725, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492', center_xyz=(-100.46, 68.01, -230.55))
# 92 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.005399015, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.281489753704424911132261151767', center_xyz=(110.14, -31.2, -241.36))
# 93 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.06186005, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.250863365157630276148828903732', center_xyz=(-83.1930640477, -29.0767194265, -153.227780712))
# 94 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.450501966058662668272378865145', center_xyz=(97.74, -33.97, 130.72))
# 95 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.621579517, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.139258777898746693365877042411', center_xyz=(-106.98605025, -177.74552385, -192.46801265))
# 96 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.165672419, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.323302986710576400812869264321', center_xyz=(-77.6742804778, 24.6389385283, -107.581430893))
# 97 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.21739005, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.640729228179368154416184318668', center_xyz=(-113.17, -225.85, -199.99))
# 98 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.313818163, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.826812708000318290301835871780', center_xyz=(-53.5, -50.62, -137.83))
# 99 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.756615445, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.511347030803753100045216493273', center_xyz=(-85.0178411434, 23.7094197723, -220.666696981))

# %%
series_uid = positiveSample_list[11][2]
showCandidate(series_uid)
# Out:
# 2023-08-11 01:06:57,792 INFO     pid:348 p2ch10.dsets:177:__init__ <p2ch10.dsets.LunaDataset object at 0x7a66456e9870>: 539 training samples
# <div id='8cdcf82c-6828-4792-80f7-850a322e294f'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.716498695101447665580610403574 73 False [73]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565'
showCandidate(series_uid)
# Out:
# 2023-08-11 01:07:07,872 INFO     pid:348 p2ch10.dsets:177:__init__ <p2ch10.dsets.LunaDataset object at 0x7a66456eb2b0>: 1061 training samples
# <div id='d21538aa-4d47-447d-805c-fac468a7e4c7'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565 14 False [14]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354'
showCandidate(series_uid)
# Out:
# 2023-08-11 01:07:12,462 INFO     pid:348 p2ch10.dsets:177:__init__ <p2ch10.dsets.LunaDataset object at 0x7a66456eae60>: 605 training samples
# <div id='8d77c697-05f9-4b6a-8f51-d13b9fcd37e4'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354 440 False [440]

# %%
LunaDataset()[0]
# Out:
# 2020-07-26 14:43:16,465 INFO     pid:9828 p2ch10.dsets:212:__init__ <p2ch10.dsets.LunaDataset object at 0x00000186979F96A0>: 551065 training samples
# (tensor([[[[-732., -810., -863.,  ..., -848., -865., -890.],
#            [-767., -826., -855.,  ..., -908., -896., -879.],
#            [-807., -859., -848.,  ..., -898., -903., -897.],
#            ...,
#            [-874., -869., -839.,  ..., -159., -121., -104.],
#            [-923., -930., -911.,  ..., -115., -104., -117.],
#            [-898., -898., -901.,  ...,  -89.,  -93., -129.]],
#
#           [[-776., -779., -860.,  ..., -852., -875., -874.],
#            [-839., -834., -889.,  ..., -875., -894., -898.],
#            [-861., -857., -882.,  ..., -838., -865., -889.],
#            ...,
#            [-862., -932., -917.,  ..., -111.,  -94., -101.],
#            [-896., -918., -898.,  ...,  -16.,    1.,  -41.],
#            [-875., -894., -881.,  ...,  -55.,  -47.,  -83.]],
#
#           [[-854., -898., -884.,  ..., -886., -878., -857.],
#            [-856., -876., -865.,  ..., -869., -880., -884.],
#            [-841., -859., -881.,  ..., -857., -844., -832.],
#            ...,
#            [-744., -880., -873.,  ...,  -95.,  -55.,  -40.],
#            [-858., -895., -870.,  ...,  -57.,    4.,    4.],
#            [-892., -897., -888.,  ...,  -54.,  -23.,  -22.]],
#
#           ...,
#
#           [[-901., -885., -877.,  ...,  -11.,    5.,   20.],
#            [-909., -883., -881.,  ...,  -14.,   -3.,   29.],
#            [-925., -911., -895.,  ...,  -35.,   -1.,   31.],
#            ...,
#            [ 373.,  436.,  473.,  ...,   17.,   29.,   26.],
#            [ 413.,  439.,  458.,  ...,  -39.,  -20.,  -11.],
#            [ 334.,  296.,  302.,  ...,    7.,   20.,   36.]],
#
#           [[-911., -909., -894.,  ...,  -16.,  -16.,   11.],
#            [-935., -920., -903.,  ...,   12.,    6.,   20.],
#            [-936., -919., -886.,  ...,    6.,   26.,   33.],
#            ...,
#            [   0.,   37.,   49.,  ...,   26.,   41.,   32.],
#            [  60.,   36.,   51.,  ...,   -4.,   -6.,   -9.],
#            [ 213.,  153.,  114.,  ...,  -31.,  -12.,    1.]],
#
#           [[-949., -950., -956.,  ...,   11.,   12.,   23.],
#            [-948., -950., -941.,  ...,   -6.,   -6.,   16.],
#            [-924., -923., -904.,  ...,  -40.,  -47.,   -9.],
#            ...,
#            [ -77.,  -85.,  -98.,  ...,   48.,   72.,   73.],
#            [ -81., -112., -106.,  ...,   50.,   72.,   85.],
#            [ -55.,  -47.,  -56.,  ...,   86.,   96.,   96.]]]]),
#  tensor([0, 1]),
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886',
#  tensor([ 91, 360, 341]))

# %%
import numpy as np
import ipyvolume as ipv
V = np.zeros((128,128,128)) # our 3d array
# outer box
V[30:-30,30:-30,30:-30] = 0.75
V[35:-35,35:-35,35:-35] = 0.0
# inner box
V[50:-50,50:-50,50:-50] = 0.25
V[55:-55,55:-55,55:-55] = 0.0
ipv.quickvolshow(V, level=[0.25, 0.75], opacity=0.03, level_width=0.1, data_min=0, data_max=1)
# Out:
# C:\Users\elis\Miniconda3\envs\book\lib\site-packages\ipyvolume\serialize.py:81: RuntimeWarning: invalid value encountered in true_divide
#   gradient = gradient / np.sqrt(gradient[0]**2 + gradient[1]**2 + gradient[2]**2)
# VBox(children=(VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, step=0.0…

# %%
ct = getCt(series_uid)
ipv.quickvolshow(ct.hu_a, level=[0.25, 0.5, 0.9], opacity=0.1, level_width=0.1, data_min=-1000, data_max=1000)
# Out:
# C:\Users\elis\Miniconda3\envs\book\lib\site-packages\ipyvolume\widgets.py:179: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data_view = self.data_original[view]
# C:\Users\elis\Miniconda3\envs\book\lib\site-packages\ipyvolume\utils.py:204: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data = (data[slices1] + data[slices2])/2
# VBox(children=(VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, step=0.0…

# %% [markdown]
# # Note: the following visualization doesn't look very good.
# It's only included here for completeness.

# %%
import scipy.ndimage.morphology
def build2dLungMask(ct, mask_ndx, threshold_gcc = 0.7):
    dense_mask = ct.hu_a[mask_ndx] > threshold_gcc
    denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
    tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
    body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
    air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)

    lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask


def build3dLungMask(ct):
    air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = mask_list = \
        [np.zeros_like(ct.hu_a, dtype=np.bool) for _ in range(6)]

    for mask_ndx in range(ct.hu_a.shape[0]):
        for i, mask_ary in enumerate(build2dLungMask(ct, mask_ndx)):
            mask_list[i][mask_ndx] = mask_ary

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask

# %%
from p2ch10.dsets import getCt
ct = getCt(series_uid)
air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = build3dLungMask(ct)

# %%
bones = ct.hu_a * (ct.hu_a > 1.5)
lungs = ct.hu_a * air_mask
ipv.figure()
ipv.pylab.volshow(bones + lungs, level=[0.17, 0.17, 0.23], data_min=100, data_max=900)
ipv.show()
# Out:
# C:\Users\elis\Miniconda3\envs\book\lib\site-packages\ipyvolume\widgets.py:179: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data_view = self.data_original[view]
# C:\Users\elis\Miniconda3\envs\book\lib\site-packages\ipyvolume\utils.py:204: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data = (data[slices1] + data[slices2])/2
# C:\Users\elis\Miniconda3\envs\book\lib\site-packages\ipyvolume\serialize.py:81: RuntimeWarning: invalid value encountered in true_divide
#   gradient = gradient / np.sqrt(gradient[0]**2 + gradient[1]**2 + gradient[2]**2)
# VBox(children=(VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.17, max=1.0, step=0.0…
