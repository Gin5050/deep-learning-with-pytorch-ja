# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch

# %%
a = torch.ones(3)
a
# Out:
# tensor([1., 1., 1.])

# %%
points = torch.zeros(6)
points[0] = 4.0
points[1] = 1.0
points[2] = 5.0
points[3] = 3.0
points[4] = 2.0
points[5] = 1.0
points
# Out:
# tensor([4., 1., 5., 3., 2., 1.])

# %%
points = torch.tensor([4., 1., 5., 3., 2., 1.])
points
# Out:
# tensor([4., 1., 5., 3., 2., 1.])

# %%
float(points[0]), float(points[1])
# Out:
# (4.0, 1.0)

# %%
points = torch.tensor([[4., 1.], [5., 3.], [2., 1.]])
points[0, 1]
# Out:
# tensor(1.)

# %%
points.shape
# Out:
# torch.Size([3, 2])

# %%
points = torch.zeros(3, 2)
points
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
some_list = list(range(6))
some_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
points[1:, :]
# Out:
# tensor([[5., 3.],
#         [2., 1.]])

# %%
img_t = torch.randn(3, 3, 5)
weights = torch.tensor([0.2126, 0.7152, 0.0722])

# %%
batch_t = torch.randn(2, 3, 5, 5) # [batch, channel, rows, columns]

# %%
img_gray_naive = img_t.mean(-3)
batch_gray_naive = batch_t.mean(-3)
img_gray_naive.shape, batch_gray_naive.shape
# Out:
# (torch.Size([3, 5]), torch.Size([2, 5, 5]))

# %%
unsqueezed_weights = weights.unsqueeze(-1).unsqueeze_(-1)
unsqueezed_weights.shape
# Out:
# torch.Size([3, 1, 1])

# %%
img_weights = (img_t * unsqueezed_weights)
img_weights.shape
# Out:
# torch.Size([3, 3, 5])

# %%
batch_weights = batch_t * unsqueezed_weights
batch_weights.shape
# Out:
# torch.Size([2, 3, 5, 5])

# %%
img_gray_weighted = img_weights.sum(-3)
batch_gray_weighted = batch_weights.sum(-3)

# %%
img_gray_weighted.shape, batch_gray_weighted.shape
# Out:
# (torch.Size([3, 5]), torch.Size([2, 5, 5]))

# %%
img_gray_weighted_fancy = torch.einsum('...chw, c->...hw', img_t, weights)
batch_gray_weighted_fancy = torch.einsum('...chw, c->...hw', batch_t, weights)
batch_gray_weighted_fancy.shape
# Out:
# torch.Size([2, 5, 5])

# %%
double_points = torch.ones(2, 2, dtype=torch.float64)
short_points = torch.tensor([[1, 2], [2, 3]], dtype=torch.short)

# %%
double_points * short_points
# Out:
# tensor([[1., 2.],
#         [2., 3.]], dtype=torch.float64)

# %%
double_points = torch.zeros(10, 2).double()
short_points = torch.ones(2, 2).short()

# %%
double_points = torch.zeros(10, 2).to(torch.float64)
short_points = torch.zeros(2, 2).to(dtype=torch.int16)

# %%
a = torch.ones(3, 4, 2)
a_t = torch.transpose(a, 0, 2)
a.shape, a_t.shape
# Out:
# (torch.Size([3, 4, 2]), torch.Size([2, 4, 3]))

# %%
a_t = a.transpose(0, 2)
a_t.shape
# Out:
# torch.Size([2, 4, 3])

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points.storage()
# Out:
# <ipython-input-53-8575ff47c9e0>:2: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   points.storage()
#  4.0
#  1.0
#  5.0
#  3.0
#  2.0
#  1.0
# [torch.storage.TypedStorage(dtype=torch.float32, device=cpu) of size 6]

# %%
points_storage = points.storage()
points_storage[0]
# Out:
# 4.0

# %%
points.storage()[1]
# Out:
# 1.0

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points_storage = points.storage()
points_storage[2] = 2.0
points
# Out:
# tensor([[4., 1.],
#         [2., 3.],
#         [2., 1.]])

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
second_point = points[1]
second_point.storage_offset()
# Out:
# 2

# %%
second_point.size()
# Out:
# torch.Size([2])

# %%
third_point = points[2]
third_point.storage_offset()
# Out:
# 4

# %%
points.stride()
# Out:
# (2, 1)

# %%
a = torch.ones(2)

# %%
a
# Out:
# tensor([1., 1.])

# %%
a.unsqueeze_(-1).unsqueeze_(-1)
a.shape
# Out:
# torch.Size([2, 1, 1])

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points.shape
# Out:
# torch.Size([3, 2])

# %%
points_t = points.t()
points_t
# Out:
# tensor([[4., 5., 2.],
#         [1., 3., 1.]])

# %%
some_t = torch.ones(3, 4, 5)
some_t.stride()
# Out:
# (20, 5, 1)

# %%
transpose_t = some_t.transpose(0, 2)
transpose_t.stride()
# Out:
# (1, 5, 20)

# %%
import torch
points_gpu = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]], device='cuda')

# %%
import torch
points = torch.tensor([[4., 1.], [5., 3.], [2., 1.]])
points_np = points.numpy()
points_np
# Out:
# array([[4., 1.],
#        [5., 3.],
#        [2., 1.]], dtype=float32)

# %%
# %cd /content/drive/MyDrive/MyStudy/dlwpt-code-ja/p1ch3
# Out:
# /content/drive/MyDrive/MyStudy/dlwpt-code-ja/p1ch3

# %%
torch.save(points, '../data/p1ch3/outpoints.t')

# %%
#かわりのテンソルの保存方法
with open('../data/p1ch3/outpoints.t', 'wb') as f:
    torch.save(points, f)

# %%
points = torch.load('../data/p1ch3/outpoints.t')

# %%
import h5py

# %%
f = h5py.File('../data/p1ch3/ourpoints.hdf5', 'w')
dset = f.create_dataset('coords', data=points.numpy())
f.close()

# %%
f = h5py.File('../data/p1ch3/ourpoints.hdf5', 'r')
dset = f['coords']
last_points = dset[-2:]
last_points
# Out:
# array([[5., 3.],
#        [2., 1.]], dtype=float32)

# %%
last_points_t = torch.from_numpy(dset[-2:])
f.close()

# %%
last_points_t
# Out:
# tensor([[5., 3.],
#         [2., 1.]])
